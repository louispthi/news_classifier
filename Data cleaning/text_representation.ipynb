# %% [markdown]
# # Text representation

# %% [markdown]
# We are now ready to use TF-IDF Vectors for our feature engineering.

# %% [markdown]
# ### Reading the files and importing the libraries

# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', 100)

# %%
path = '/Users/louispht/Documents/git_projects/news_classifier/Data cleaning/Csv_files_cleaned/'
df_all = pd.read_csv(path + 'stem_all.csv', index_col = 0, lineterminator='\n').reset_index(drop=True)

# %%
df_train = pd.read_csv(path + 'stem_train.csv', index_col = 0, lineterminator='\n').reset_index(drop=True)

# %%
df_test = pd.read_csv(path +'stem_test.csv', index_col = 0, lineterminator='\n').reset_index(drop=True)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13807 entries, 0 to 13806
# Data columns (total 6 columns):
# title              13807 non-null object
# content            13807 non-null object
# link               13807 non-null object
# category           13807 non-null object
# news_length        13807 non-null int64
# cleaned_content    13807 non-null object
# dtypes: int64(1), object(5)
# memory usage: 647.3+ KB

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12335 entries, 0 to 12334
# Data columns (total 6 columns):
# title              12335 non-null object
# content            12335 non-null object
# link               12335 non-null object
# category           12335 non-null object
# news_length        12335 non-null int64
# cleaned_content    12335 non-null object
# dtypes: int64(1), object(5)
# memory usage: 578.3+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1472 entries, 0 to 1471
# Data columns (total 6 columns):
# title              1472 non-null object
# content            1472 non-null object
# link               1472 non-null object
# category           1472 non-null object
# news_length        1472 non-null int64
# cleaned_content    1472 non-null object
# dtypes: int64(1), object(5)
# memory usage: 69.1+ KB

# %%
df_all.head(5)
# Out:
#                                                title  \
# 0   Oui, Marie-Josée Lord est une chanteuse d'opéra!
# 1                         Une vallée sans foi ni loi
# 2  Les profs dénoncent la hausse artificielle des...
# 3  18 millions pour l'ambassade et des résidences...
# 4  La semaine s'annonce explosive à l'Hôtel de Ville
#
#                                              content  \
# 0  «Je ne suis pas une chanteuse d'opéra.» Marie-...
# 1  C'était une paisible vallée agricole où les po...
# 2  Les cibles de réussite que le ministère de l'É...
# 3  Bien avant que le gouvernement conservateur de...
# 4  Le vérificateur remettra au conseil municipal,...
#
#                                                 link       category  \
# 0  https://www.lapresse.ca/arts/festivals/montrea...        culture
# 1  https://www.lapresse.ca/international/amerique...  international
# 2  https://www.lapresse.ca/actualites/education/2...     actualites
# 3  https://www.lapresse.ca/actualites/dossiers/le...     actualites
# 4  https://www.lapresse.ca/actualites/grand-montr...     actualites
#
#    news_length                                    cleaned_content
# 0         3137       chanteux oper mariejos lord  laiss tomb c...
# 1         7051    paisibl vall agricol où  polici regl  chican...
# 2         5624   cibl  réussit   minister  éduc impos depuis a...
# 3         3431  bien avant   gouvern conserv  stephen harp  co...
# 4         2983   vérif remettr  conseil municipal  soir  rappo...

# %% [markdown]
# #### LabelEncoding

# %% [markdown]
# We create labels for our categories, as it is easier to work with for our models.

# %%
#y_all = pd.get_dummies(df_all.category, prefix='cat')
#y_train = pd.get_dummies(df_train.category, prefix='cat')
#y_test = pd.get_dummies(df_test.category, prefix='cat')

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df_train.category)
y_all = le.transform(df_all.category)
y_train = le.transform(df_train.category)
y_test = le.transform(df_test.category)

# %%
y_all.shape
# Out:
# (13807,)

# %%
y_train.shape
# Out:
# (12335,)

# %%
y_test.shape
# Out:
# (1472,)

# %%
df_y_all = pd.DataFrame(data = y_all, columns = ['label_enc'])
df_y_train = pd.DataFrame(data = y_train, columns = ['label_enc'])
df_y_test = pd.DataFrame(data = y_test, columns = ['label_enc'])

# %%
df_y_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13807 entries, 0 to 13806
# Data columns (total 1 columns):
# label_enc    13807 non-null int64
# dtypes: int64(1)
# memory usage: 108.0 KB

# %%
df_y_all.head()
# Out:
#    label_enc
# 0          2
# 1          3
# 2          0
# 3          0
# 4          0

# %%
df_all['category'].head()
# Out:
# 0          culture
# 1    international
# 2       actualites
# 3       actualites
# 4       actualites
# Name: category, dtype: object

# %%
df_all_le = pd.concat([df_all, df_y_all], axis=1)
df_test_le = pd.concat([df_test, df_y_test], axis=1)
df_train_le = pd.concat([df_train, df_y_train], axis=1)

# %%
df_all_le.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13807 entries, 0 to 13806
# Data columns (total 7 columns):
# title              13807 non-null object
# content            13807 non-null object
# link               13807 non-null object
# category           13807 non-null object
# news_length        13807 non-null int64
# cleaned_content    13807 non-null object
# label_enc          13807 non-null int64
# dtypes: int64(2), object(5)
# memory usage: 755.2+ KB

# %%
df_train_le.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12335 entries, 0 to 12334
# Data columns (total 7 columns):
# title              12335 non-null object
# content            12335 non-null object
# link               12335 non-null object
# category           12335 non-null object
# news_length        12335 non-null int64
# cleaned_content    12335 non-null object
# label_enc          12335 non-null int64
# dtypes: int64(2), object(5)
# memory usage: 674.7+ KB

# %%
df_test_le.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1472 entries, 0 to 1471
# Data columns (total 7 columns):
# title              1472 non-null object
# content            1472 non-null object
# link               1472 non-null object
# category           1472 non-null object
# news_length        1472 non-null int64
# cleaned_content    1472 non-null object
# label_enc          1472 non-null int64
# dtypes: int64(2), object(5)
# memory usage: 80.6+ KB

# %%
df_test_le.sample(10)
# Out:
#                                                   title  \
# 1405    Kim Gingras dévoile les secrets de sa carrière
# 539   F1 : malgré la COVID-19, le GP de Toscane pour...
# 1340                  Rien ne va plus pour les Raptors
# 216   La Chine promet «une réponse» aux restrictions...
# 1151            Le Drakkar tient le coup face aux Sags
# 936         La fabuleuse histoire du melon de Montréal
# 882      Fin de la période de grâce pour les vignettes
# 102   Garderies en milieu familial: reprise des négo...
# 345             Rogers étend son réseau 5G à 50 marchés
# 29    Legault affiche un «nationalisme économique d’...
#
#                                                 content  \
# 1405  Comment arrive-t-on à danser avec les plus gra...
# 539   Une course de Formule 1 qui se déroulera en It...
# 1340  Les Raptors de Toronto ont subi un deuxième re...
# 216   (Pékin) La Chine a promis jeudi « une réponse ...
# 1151  BAIE-COMEAU | Le Drakkar de Baie-Comeau a sout...
# 936   Vers la fin du 19e siècle, on retrouvait envir...
# 882   MONTRÉAL | La Ville de Montréal a annoncé, dim...
# 102   (Montréal) Les négociations entre la Fédératio...
# 345   (Toronto) Rogers Communications étend la techn...
# 29    (Québec) Le premier ministre du Québec, Franço...
#
#                                                    link       category  \
# 1405  https://www.journaldemontreal.com/2020/08/17/k...        culture
# 539   https://www.lapresse.ca/sports/course-automobi...         sports
# 1340  https://www.journaldemontreal.com/2020/09/01/r...         sports
# 216   https://www.lapresse.ca/international/asie-et-...  international
# 1151  https://www.journaldemontreal.com/2020/09/05/l...         sports
# 936   https://www.journaldemontreal.com/2020/09/04/l...     actualites
# 882   https://www.journaldemontreal.com/2020/08/30/f...     actualites
# 102   https://www.lapresse.ca/actualites/education/2...     actualites
# 345   https://www.lapresse.ca/affaires/techno/2020-0...       affaires
# 29    https://www.lapresse.ca/actualites/politique/2...     actualites
#
#       news_length                                    cleaned_content  \
# 1405         3414  comment arriv  dans   plus grand star   planet...
# 539          1083   cours  formule1   déroul  ital pourr accueil ...
# 1340         3183   raptor  toronto  sub  deuxiem rever consécut ...
# 216          1822  pékin  chin  prom jeud  répons appropri  néces...
# 1151         2587  baiecomeau |  drakkar  baiecomeau  soutir  dou...
# 936          5776  ver  fin  19e siecl  retrouv environ 1400 agri...
# 882          1084  montréal |  vill  montréal  annonc dimanch  fi...
# 102          2332  montréal  négoci entre  féder  interven  petit...
# 345          3122  toronto roger commun étend  technologie5g  50n...
# 29           3779  québec  premi ministr  québec françois legault...
#
#       label_enc
# 1405          2
# 539           4
# 1340          4
# 216           3
# 1151          4
# 936           0
# 882           0
# 102           0
# 345           1
# 29            0

# %% [markdown]
# #### Text representation

# %% [markdown]
# We use 'TF-IDF' Vectors as our feature engineering. We first set the parameters, these could be adjusted for better results. For example, too much features could cause overfitting issues.

# %%
X_train = df_train['cleaned_content']
X_test = df_test['cleaned_content']

# %%
# Setting parameters 
ngram_range = (1,1)
min_df = 300
max_df = 0.75
max_features = 500

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(encoding='utf-8',
                        ngram_range=ngram_range,
                        stop_words=None,
                        lowercase=False,
                        max_df=max_df,
                        min_df=min_df,
                        max_features=max_features,
                        norm='l2',
                        sublinear_tf=True)
                        
features_train = tfidf.fit_transform(X_train).toarray()
print(features_train.shape)

features_test = tfidf.transform(X_test).toarray()
print(features_test.shape)
# Out:
# (12335, 500)
# (1472, 500)

# %% [markdown]
# We get the feature names.

# %%
feature_names = np.array(tfidf.get_feature_names())

# %%
feature_names
# Out:
# array(['000', '10', '12', '15', '20', '2015', '2016', '25', '30', 'accord',
#        'accus', 'action', 'activ', 'actuel', 'administr', 'affair',
#        'affirm', 'afin', 'afp', 'agenc', 'aid', 'ailleur', 'aim', 'ains',
#        'ajout', 'aller', 'alor', 'américain', 'an', 'ancien', 'annonc',
#        'anné', 'appel', 'apres', 'argent', 'armé', 'arriv', 'arrêt',
#        'artist', 'associ', 'assur', 'attaqu', 'aucun', 'augment', 'auss',
#        'aut', 'autor', 'autr', 'avanc', 'avant', 'avocat', 'avoir',
#        'avril', 'bas', 'beaucoup', 'bel', 'besoin', 'bien', 'bless', 'bon',
#        'but', 'campagn', 'canad', 'canadien', 'capital', 'car', 'carri',
#        'cas', 'caus', 'cel', 'celui', 'centr', 'certain', 'cet', 'ceux',
#        'chang', 'chaqu', 'chef', 'chez', 'chin', 'choix', 'chos', 'cinq',
#        'class', 'comm', 'commenc', 'comment', 'commun', 'communiqu',
#        'compagn', 'complet', 'compt', 'confirm', 'connu', 'conseil',
#        'conserv', 'consider', 'continu', 'contr', 'contrat', 'contrôl',
#        'coup', 'cour', 'cours', 'covid19', 'coût', 'cris', 'cré', 'côt',
#        'demand', 'depuis', 'derni', 'des', 'deux', 'deuxiem', 'dev',
#        'devr', 'difficil', 'différent', 'dimanch', 'dir', 'direct',
#        'directeur', 'dirig', 'dit', 'doit', 'dollar', 'don', 'donald',
#        'donc', 'dont', 'dossi', 'droit', 'dur', 'début', 'décembr',
#        'décid', 'décis', 'déclar', 'défens', 'déjà', 'démocrat', 'départ',
#        'développ', 'effet', 'elle', 'emploi', 'encor', 'enfant', 'engag',
#        'enquêt', 'ensembl', 'ensuit', 'entraîn', 'entre', 'entrepris',
#        'environ', 'estim', 'européen', 'expliqu', 'fac', 'fair', 'fais',
#        'fait', 'famill', 'faut', 'façon', 'femm', 'ferm', 'fil', 'film',
#        'fin', 'final', 'financ', 'financi', 'fois', 'fond', 'font', 'forc',
#        'format', 'fort', 'franc', 'fédéral', 'févri', 'gagn', 'gard',
#        'gen', 'gouvern', 'grand', 'group', 'guerr', 'général', 'hauss',
#        'haut', 'heur', 'hi', 'histoir', 'hockey', 'homm', 'hôpital', 'ici',
#        'impact', 'import', 'indiqu', 'inform', 'international', 'invest',
#        'jam', 'janvi', 'jeu', 'jeud', 'jeun', 'jeux', 'jou', 'joueur',
#        'jour', 'journ', 'journal', 'jug', 'juin', 'jusqu', 'just',
#        'justic', 'laiss', 'lanc', 'leur', 'lieu', 'lign', 'ligu', 'lir',
#        'livr', 'local', 'loi', 'long', 'lor', 'lorsqu', 'lund', 'là',
#        'main', 'mainten', 'maison', 'mal', 'malgr', 'manifest', 'mar',
#        'march', 'mard', 'marqu', 'match', 'matin', 'meilleur', 'membr',
#        'men', 'menac', 'mer', 'mercred', 'mesur', 'mettr', 'mieux',
#        'milliard', 'million', 'minister', 'ministr', 'minut', 'mis', 'mme',
#        'moin', 'mois', 'moment', 'mond', 'mondial', 'mont', 'montr',
#        'montréal', 'mort', 'moyen', 'médecin', 'médi', 'national', 'new',
#        'ni', 'niveau', 'nom', 'nombr', 'nombreux', 'non', 'nord', 'not',
#        'nouveau', 'nouvel', 'novembr', 'occas', 'officiel', 'oper', 'or',
#        'organis', 'ouvert', 'où', 'pai', 'parc', 'parl', 'parm', 'part',
#        'particip', 'particuli', 'pass', 'pay', 'pend', 'pens', 'per',
#        'perdu', 'perm', 'permet', 'permettr', 'person', 'personnel', 'pet',
#        'petit', 'peu', 'peut', 'peuvent', 'plac', 'plan', 'plein', 'plus',
#        'plusieur', 'plutôt', 'point', 'polic', 'polici', 'polit', 'port',
#        'porteparol', 'posit', 'possibl', 'post', 'pourr', 'pouv',
#        'pouvoir', 'premi', 'prendr', 'pres', 'press', 'principal', 'pris',
#        'prix', 'problem', 'prochain', 'product', 'produit', 'programm',
#        'projet', 'propos', 'provinc', 'précis', 'présent', 'président',
#        'prévu', 'prêt', 'pu', 'publi', 'public', 'publiqu', 'puis',
#        'périod', 'quand', 'quatr', 'quel', 'quelqu', 'question', 'québec',
#        'québécois', 'racont', 'raison', 'rang', 'rapid', 'rappel',
#        'rapport', 'recherch', 'regl', 'relat', 'remport', 'rencontr',
#        'représent', 'respect', 'respons', 'rest', 'retour', 'retrouv',
#        'reçu', 'rien', 'risqu', 'ru', 'russ', 'réalis', 'récent', 'région',
#        'réseau', 'résultat', 'réuss', 'saison', 'samed', 'san', 'sant',
#        'savoir', 'scen', 'secteur', 'selon', 'semain', 'sembl', 'sept',
#        'ser', 'servic', 'seul', 'si', 'sign', 'sit', 'situat', 'six',
#        'social', 'societ', 'soir', 'sort', 'soulign', 'sous', 'souvent',
#        'spectacl', 'spécial', 'sud', 'suit', 'suiv', 'surtout', 'system',
#        'sécur', 'tard', 'tel', 'temp', 'tent', 'term', 'termin', 'the',
#        'tir', 'titr', 'toronto', 'total', 'touch', 'toujour', 'tour',
#        'tourn', 'tous', 'tout', 'toutefois', 'trait', 'transport',
#        'travail', 'travaill', 'tres', 'trois', 'troisiem', 'trop', 'trouv',
#        'trump', 'tu', 'têt', 'utilis', 'va', 'ven', 'vendred', 'vent',
#        'ver', 'veut', 'vi', 'victim', 'victoir', 'vill', 'vis', 'voi',
#        'voir', 'vol', 'vont', 'vot', 'vrai', 'vu', 'washington', 'york',
#        'ça', 'écol', 'économ', 'écrit', 'égal', 'élect', 'élev', 'équip',
#        'établ', 'état', 'étatsun', 'étud', 'éven', 'êtr', 'être'],
#       dtype='<U13')

# %%
from sklearn.feature_selection import chi2
categories = {'actualite':0, 'sports':4, 'international':3, 'affaires':1, 'culture':2}

for cat, label in sorted(categories.items()):
    features_chi2 = chi2(features_train, y_train == label)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    words = [v for v in feature_names if len(v.split(' ')) == 1]
    print("# '{}' category:".format(cat))
    print("  Most correlated words:\n. {}".format('\n. '.join(words[-10:])))
    print("")
# Out:
# # 'actualite' category:
#   Most correlated words:
# . mme
# . ru
# . transport
# . américain
# . ministr
# . joueur
# . saison
# . polici
# . match
# . québec
#
# # 'affaires' category:
#   Most correlated words:
# . action
# . vent
# . économ
# . invest
# . march
# . financi
# . dollar
# . milliard
# . hauss
# . entrepris
#
# # 'culture' category:
#   Most correlated words:
# . racont
# . match
# . histoir
# . réalis
# . tourn
# . the
# . scen
# . spectacl
# . artist
# . film
#
# # 'international' category:
#   Most correlated words:
# . mort
# . tu
# . pay
# . état
# . armé
# . démocrat
# . président
# . afp
# . donald
# . trump
#
# # 'sports' category:
#   Most correlated words:
# . remport
# . jeu
# . hockey
# . victoir
# . équip
# . ligu
# . but
# . saison
# . joueur
# . match

# %% [markdown]
# Strangely, the category 'actualities' seem to have words highly corrolated with 'sports' words. One explanation is that 'actualities' is a fairly vaguely defined category, which can encompass many types of articles. We will see how this will affect our model.
#
# Also, one could consider bigrams and trigrams. This could have added more specific features to each categories.

# %% [markdown]
# #### Saving the files

# %% [markdown]
# We use Pickle to store the different variables.

# %%
import pickle

# %%
# X_train
with open('Pickles/X_train.pickle', 'wb') as output:
    pickle.dump(X_train, output)
    
# X_test    
with open('Pickles/X_test.pickle', 'wb') as output:
    pickle.dump(X_test, output)
    
# y_train
with open('Pickles/y_train.pickle', 'wb') as output:
    pickle.dump(y_train, output)
    
# y_test
with open('Pickles/y_test.pickle', 'wb') as output:
    pickle.dump(y_test, output)
    
# df_all
with open('Pickles/df_all.pickle', 'wb') as output:
    pickle.dump(df_all, output)
    
# df_train
with open('Pickles/df_train.pickle', 'wb') as output:
    pickle.dump(df_train, output)
    
# df_test
with open('Pickles/df_test.pickle', 'wb') as output:
    pickle.dump(df_test, output)

# df_all_le
with open('Pickles/df_all_le.pickle', 'wb') as output:
    pickle.dump(df_all_le, output)
    
# df_train_le
with open('Pickles/df_train_le.pickle', 'wb') as output:
    pickle.dump(df_train_le, output)
    
# df_test_le
with open('Pickles/df_test_le.pickle', 'wb') as output:
    pickle.dump(df_test_le, output)
    
# features_train
with open('Pickles/features_train.pickle', 'wb') as output:
    pickle.dump(features_train, output)

# features_test
with open('Pickles/features_test.pickle', 'wb') as output:
    pickle.dump(features_test, output)
    
# TF-IDF object
with open('Pickles/tfidf.pickle', 'wb') as output:
    pickle.dump(tfidf, output)
