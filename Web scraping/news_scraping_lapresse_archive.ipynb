# %% [markdown]
# # Scraping the archived news from La Presse

# %% [markdown]
# We use web scraping with the help of BeautifulSoup to create a dataset. This is a scraping of the archived news from La Presse, which we will use to train our models. We label our datas into 5 categories: 'Sports', 'Culture', 'Actualite', 'International' and 'Affaires'

# %% [markdown]
# We will obtain the news from 50 random days from 2011 to 2020 (5 per year). If we were to obtain all the datas from the same time period, this could influence the outcome, as they would probably be talking about similar subjects.

# %% [markdown]
# We import the relevant libraries.

# %%
from requests import get
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %% [markdown]
# We will only collect the news from the following list of subcategories.

# %%
#Put the different subsections into a list
#Actualites 
sub_act_list = ['national', 'politique', 'grand-montreal', 'regional',
                'justice-et-faits-divers', 'sante', 'education', 'enquetes',
                'insolite', 'environnement', 'sciences']
#International 
sub_int_list = ['afrique', 'amerique-latine', 'asie-et-oceanie', 
               'caraibes', 'etats-unis', 'europe', 'moyen-orient']

#Affaires 
sub_aff_list = ['economie', 'marches', 'entreprises', 'techno', 'medias',
               'finances-personnelles', 'pme', 'portfolio', 'tetes-daffiche']
#Sports 
sub_spo_list = ['hockey', 'tokyo-2020', 'soccer', 'football', 'tennis',
               'baseball', 'course-automobile', 'golf', 'sports-de-combat', 
               'sports-dhiver', 'basketball', 'cyclisme']
#Culture 
sub_cul_arts_list = ['musique', 'television', 'theatre', 'litterature', 
                    'arts-visuels', 'spectacles', 'humour', 'celebrites']
sub_cul_cinema_list = ['cinema']

#Concatenated list 
sub_lp_list = sub_act_list +sub_int_list + sub_aff_list + sub_spo_list + sub_cul_arts_list + sub_cul_cinema_list

# %% [markdown]
# The archives in La Presse are in a site which has an url of the form "https://www.lapresse.ca/archives/DATE.php", where DATE has format YYYY/m/d.

# %%
# Create a list of urls for 50 random dates
import random
random.seed(42)

years = list(range(2011, 2021))
urls = []
i = 0
days = [random.randint(1,28) for i in range(0,50)]
months = [random.randint(1,12) for i in range(0,45)]

#2020 is not complete, so we make sure the date is from the past
months_2020 = [random.randint(1,8) for i in range(0,5)]

while i <10: 
    j = 0
    year = str(years[i])
    while j < 5:
        n = 5*i + j
        day = str(days[n])
        if i == 9:
            month = str(months_2020[j])
        else:
            month = str(months[n])
        url_temp = 'https://www.lapresse.ca/archives/' + year + '/' + month + '/' + day + '.php'
        urls.append(url_temp)
        j = j+1
    i = i+1

# %% [markdown]
# We check to see if it worked.

# %%
urls
# Out:
# ['https://www.lapresse.ca/archives/2011/2/21.php',
#  'https://www.lapresse.ca/archives/2011/7/4.php',
#  'https://www.lapresse.ca/archives/2011/2/1.php',
#  'https://www.lapresse.ca/archives/2011/6/24.php',
#  'https://www.lapresse.ca/archives/2011/6/9.php',
#  'https://www.lapresse.ca/archives/2012/10/8.php',
#  'https://www.lapresse.ca/archives/2012/5/8.php',
#  'https://www.lapresse.ca/archives/2012/1/5.php',
#  'https://www.lapresse.ca/archives/2012/12/24.php',
#  'https://www.lapresse.ca/archives/2012/8/4.php',
#  'https://www.lapresse.ca/archives/2013/9/22.php',
#  'https://www.lapresse.ca/archives/2013/2/24.php',
#  'https://www.lapresse.ca/archives/2013/7/18.php',
#  'https://www.lapresse.ca/archives/2013/2/3.php',
#  'https://www.lapresse.ca/archives/2013/9/19.php',
#  'https://www.lapresse.ca/archives/2014/5/14.php',
#  'https://www.lapresse.ca/archives/2014/11/2.php',
#  'https://www.lapresse.ca/archives/2014/10/1.php',
#  'https://www.lapresse.ca/archives/2014/6/3.php',
#  'https://www.lapresse.ca/archives/2014/10/7.php',
#  'https://www.lapresse.ca/archives/2015/4/8.php',
#  'https://www.lapresse.ca/archives/2015/12/17.php',
#  'https://www.lapresse.ca/archives/2015/2/20.php',
#  'https://www.lapresse.ca/archives/2015/1/1.php',
#  'https://www.lapresse.ca/archives/2015/11/18.php',
#  'https://www.lapresse.ca/archives/2016/4/7.php',
#  'https://www.lapresse.ca/archives/2016/5/23.php',
#  'https://www.lapresse.ca/archives/2016/2/21.php',
#  'https://www.lapresse.ca/archives/2016/4/23.php',
#  'https://www.lapresse.ca/archives/2016/2/18.php',
#  'https://www.lapresse.ca/archives/2017/7/14.php',
#  'https://www.lapresse.ca/archives/2017/5/8.php',
#  'https://www.lapresse.ca/archives/2017/8/15.php',
#  'https://www.lapresse.ca/archives/2017/11/19.php',
#  'https://www.lapresse.ca/archives/2017/6/9.php',
#  'https://www.lapresse.ca/archives/2018/3/26.php',
#  'https://www.lapresse.ca/archives/2018/6/28.php',
#  'https://www.lapresse.ca/archives/2018/6/1.php',
#  'https://www.lapresse.ca/archives/2018/4/25.php',
#  'https://www.lapresse.ca/archives/2018/11/26.php',
#  'https://www.lapresse.ca/archives/2019/5/6.php',
#  'https://www.lapresse.ca/archives/2019/12/23.php',
#  'https://www.lapresse.ca/archives/2019/11/14.php',
#  'https://www.lapresse.ca/archives/2019/11/11.php',
#  'https://www.lapresse.ca/archives/2019/2/9.php',
#  'https://www.lapresse.ca/archives/2020/3/5.php',
#  'https://www.lapresse.ca/archives/2020/4/7.php',
#  'https://www.lapresse.ca/archives/2020/3/25.php',
#  'https://www.lapresse.ca/archives/2020/8/11.php',
#  'https://www.lapresse.ca/archives/2020/7/4.php']

# %% [markdown]
# We make sure there are no duplicates.

# %%
len(urls) == len(set(urls))
# Out:
# True

# %% [markdown]
# We create requests.

# %%
#Requests
headers = {'Accept': 'text/html', 'User-Agent':'Mozilla/5.0'}
response_lp = {}
for url in urls:
    response_lp[url] = get(url, headers = headers)
    print("Status for", url, "is", response_lp[url].status_code)
# Out:
# Status for https://www.lapresse.ca/archives/2011/2/21.php is 200
# Status for https://www.lapresse.ca/archives/2011/7/4.php is 200
# Status for https://www.lapresse.ca/archives/2011/2/1.php is 200
# Status for https://www.lapresse.ca/archives/2011/6/24.php is 200
# Status for https://www.lapresse.ca/archives/2011/6/9.php is 200
# Status for https://www.lapresse.ca/archives/2012/10/8.php is 200
# Status for https://www.lapresse.ca/archives/2012/5/8.php is 200
# Status for https://www.lapresse.ca/archives/2012/1/5.php is 200
# Status for https://www.lapresse.ca/archives/2012/12/24.php is 200
# Status for https://www.lapresse.ca/archives/2012/8/4.php is 200
# Status for https://www.lapresse.ca/archives/2013/9/22.php is 200
# Status for https://www.lapresse.ca/archives/2013/2/24.php is 200
# Status for https://www.lapresse.ca/archives/2013/7/18.php is 200
# Status for https://www.lapresse.ca/archives/2013/2/3.php is 200
# Status for https://www.lapresse.ca/archives/2013/9/19.php is 200
# Status for https://www.lapresse.ca/archives/2014/5/14.php is 200
# Status for https://www.lapresse.ca/archives/2014/11/2.php is 200
# Status for https://www.lapresse.ca/archives/2014/10/1.php is 200
# Status for https://www.lapresse.ca/archives/2014/6/3.php is 200
# Status for https://www.lapresse.ca/archives/2014/10/7.php is 200
# Status for https://www.lapresse.ca/archives/2015/4/8.php is 200
# Status for https://www.lapresse.ca/archives/2015/12/17.php is 200
# Status for https://www.lapresse.ca/archives/2015/2/20.php is 200
# Status for https://www.lapresse.ca/archives/2015/1/1.php is 200
# Status for https://www.lapresse.ca/archives/2015/11/18.php is 200
# Status for https://www.lapresse.ca/archives/2016/4/7.php is 200
# Status for https://www.lapresse.ca/archives/2016/5/23.php is 200
# Status for https://www.lapresse.ca/archives/2016/2/21.php is 200
# Status for https://www.lapresse.ca/archives/2016/4/23.php is 200
# Status for https://www.lapresse.ca/archives/2016/2/18.php is 200
# Status for https://www.lapresse.ca/archives/2017/7/14.php is 200
# Status for https://www.lapresse.ca/archives/2017/5/8.php is 200
# Status for https://www.lapresse.ca/archives/2017/8/15.php is 200
# Status for https://www.lapresse.ca/archives/2017/11/19.php is 200
# Status for https://www.lapresse.ca/archives/2017/6/9.php is 200
# Status for https://www.lapresse.ca/archives/2018/3/26.php is 200
# Status for https://www.lapresse.ca/archives/2018/6/28.php is 200
# Status for https://www.lapresse.ca/archives/2018/6/1.php is 200
# Status for https://www.lapresse.ca/archives/2018/4/25.php is 200
# Status for https://www.lapresse.ca/archives/2018/11/26.php is 200
# Status for https://www.lapresse.ca/archives/2019/5/6.php is 200
# Status for https://www.lapresse.ca/archives/2019/12/23.php is 200
# Status for https://www.lapresse.ca/archives/2019/11/14.php is 200
# Status for https://www.lapresse.ca/archives/2019/11/11.php is 200
# Status for https://www.lapresse.ca/archives/2019/2/9.php is 200
# Status for https://www.lapresse.ca/archives/2020/3/5.php is 200
# Status for https://www.lapresse.ca/archives/2020/4/7.php is 200
# Status for https://www.lapresse.ca/archives/2020/3/25.php is 200
# Status for https://www.lapresse.ca/archives/2020/8/11.php is 200
# Status for https://www.lapresse.ca/archives/2020/7/4.php is 200

# %% [markdown]
# We create a soup.

# %%
#Save the main page content
mainpage_lp = {}
for url in urls:
    mainpage_lp[url] = response_lp[url].content 

#Soup Creation 
soup_lp = {}
for url in urls:
    soup_lp[url] = BeautifulSoup(mainpage_lp[url], 'html.parser')

# %% [markdown]
# We parse each article.

# %%
headline_lp = {}
for url in urls:
    for ultag in soup_lp[url].find_all("ul", class_ = 'square square-spread'):
        headline_lp[url] = ultag.find_all('li')
headline_lp['https://www.lapresse.ca/archives/2012/5/8.php'][1]
# Out:
# <li>(07:00) <a alt="Un après-midi avec les bonobos" href="https://www.lapresse.ca/voyage/destinations/afrique/201205/07/01-4522889-un-apres-midi-avec-les-bonobos.php" title="Un après-midi avec les bonobos">Un après-midi avec les bonobos</a></li>

# %% [markdown]
# From this, we see that we can easily extract the title and the description of each article, as well as the link for the complete article. We will use that to go to the article and extract the title and full text.

# %%
articles = {}
titles = {}
links = {}

# Loop over each subsection in the dictionnary
for url in urls: 
    #Create lists
    articles[url] = []
    titles[url] = []
    links[url] = []
    
    #Loop over each article in a section 
    for n in np.arange(0, len(headline_lp[url])):
        if headline_lp[url][n].find('a')['title'] is None:
            print('NonType in sub', url, 'number', n)
        else:
        
            #Access link to the article 
            link = headline_lp[url][n].find('a')['href']
            
        
            #Getting the title
            title = headline_lp[url][n].find('a')['title']
        
            #Getting the content of the article
            article = get(link)
            article_content = article.content
            soup_article = BeautifulSoup(article_content, 'html.parser')
            body = soup_article.find_all('div', class_ = 'articleBody')
            if len(body) ==0:
                print('Empty body in sub', url, 'number', n)
            else:
                x = body[0].find_all('p', {'class' : ['lead textModule textModule--type-lead ', 'paragraph textModule textModule--type-paragraph ']}) 
        
                #Unifying the paragraphs
                list_paragraphs = []
                for p in np.arange(0, len(x)):
                    paragraph = x[p].get_text()
                    list_paragraphs.append(paragraph)
                    final_article = " ".join(list_paragraphs)
        
                articles[url].append(final_article)
                links[url].append(link)
                titles[url].append(title)
# Out:
# Empty body in sub https://www.lapresse.ca/archives/2014/6/3.php number 5
# Empty body in sub https://www.lapresse.ca/archives/2017/5/8.php number 91
# Empty body in sub https://www.lapresse.ca/archives/2018/3/26.php number 24
# Empty body in sub https://www.lapresse.ca/archives/2018/6/1.php number 0
# Empty body in sub https://www.lapresse.ca/archives/2018/4/25.php number 104
# Empty body in sub https://www.lapresse.ca/archives/2018/11/26.php number 0
# Empty body in sub https://www.lapresse.ca/archives/2018/11/26.php number 1
# Empty body in sub https://www.lapresse.ca/archives/2019/5/6.php number 0
# Empty body in sub https://www.lapresse.ca/archives/2019/5/6.php number 3
# Empty body in sub https://www.lapresse.ca/archives/2019/5/6.php number 62
# Empty body in sub https://www.lapresse.ca/archives/2019/11/11.php number 0
# Empty body in sub https://www.lapresse.ca/archives/2020/4/7.php number 1
# Empty body in sub https://www.lapresse.ca/archives/2020/7/4.php number 1

# %% [markdown]
# Since the number of errors is low compared to the total number of datas, we leave it as is for now. We check a few examples to make sure the algorithm worked.

# %%
titles['https://www.lapresse.ca/archives/2018/3/26.php']
# Out:
# ["Mon clin d'oeil du lundi 26 mars 2018",
#  'Arcade Fire couronné au gala des prix Juno',
#  'Les femmes du\xa0président',
#  'Partis, quelles données utilisez-vous?',
#  'Doug Ford et le\xa0casse-tête ontarien',
#  'Dure semaine pour la CAQ',
#  "Expulsion imminente d'une Guatémaltèque: «Nous ne savons plus quoi faire»",
#  "Des jumeaux «cosmiques» révèlent les effets de l'espace",
#  "Québec doit en faire plus pour reconnaître les diplômes étrangers, selon l'IDQ",
#  'Tuerie à la mosquée de Québec: Bissonnette plaide non coupable',
#  'Remorquages sauvages: une entreprise de Montréal sous la loupe',
#  'Carles Puigdemont reste en détention en Allemagne',
#  'Philips choisit une entreprise montréalaise pour son\xa0échographe portable',
#  "Le fabricant d'armes Remington en difficulté",
#  'Obèse... mais en santé',
#  'Triomphe assuré pour Sissi à la présidentielle en Égypte',
#  'Agences de voyages: des fraudeurs se paient des forfaits tout inclus',
#  'Trudeau innocente six chefs autochtones exécutés il y a plus de 150 ans',
#  'Nétanyahou à nouveau interrogé dans une affaire de corruption présumée',
#  'Ghouta: le régime syrien entrevoit la victoire après des évacuations massives',
#  "Guerre commerciale: la Chine fustige «l'intimidation» américaine",
#  'À suivre cette semaine',
#  'Riyad menace à nouveau Téhéran après des tirs de missiles de rebelles yéménites',
#  'Référendum au Bloc: une question de quatre lignes sur la mission du parti',
#  'Washington et les Occidentaux expulsent plus de 110\xa0diplomates russes',
#  'Half Moon Run en\xa0pleine possession de ses moyens',
#  "L'idiot: compassion!",
#  'TLMEP: la révolution est dans le pré',
#  'Expos: en souvenir de 1994',
#  'La dégradation des sols causera des migrations massives',
#  'Ellis Valentine: le coeur sur la main',
#  'Blue Jays: Guerrero et Bichette, version\xa02.0',
#  'Le dialogue entre Pékin et Washington relance les marchés',
#  'Bons plans à Mexico avec les enfants',
#  'Facebook: trois utilisateurs canadiens sur quatre changeront leur façon de faire',
#  'Ça chauffe à Lac-Brome!',
#  "Échec d'une première tentative de faire avorter le procès Normandeau",
#  'Claude Julien: «Je veux voir les joueurs compétitionner»',
#  'Cinq bouteilles pour Pâques',
#  "Plateforme Kiid: à\xa0«trois clics» d'une gardienne",
#  'Bébé abandonné dans un logement en flammes: la gardienne plaide coupable',
#  'Expulsion de diplomates russes: Moscou dénonce une «provocation»',
#  'Montréal complètement cirque: les soeurs de\xa0Lhasa de\xa0Sela présenteront Sisters',
#  'Nick Foligno sur la touche pour deux à quatre semaines',
#  'Red Wings 2 - Canadien 4 (marque finale)',
#  'Tiger Woods participera à son tournoi caritatif',
#  'Céline Dion: la diva qui a changé Las Vegas',
#  'Intelligence artificielle: démystifier le concept',
#  'Cézanne le portraitiste exposé à Washington',
#  "Des règles plus souples pour la prescription de méthadone et d'héroïne",
#  'Boeing serait une cible «facile» dans une guerre commerciale',
#  "Longueuil: un système d'alarme pour des femmes victimes de violence conjugale",
#  'Une entente sur le papier surcalandré pourrait offrir du répit à Résolu',
#  'Québec accorde 150 millions pour le développement économique de Montréal',
#  'Jalouse vu par\xa0Karin Viard et Anne Dorval',
#  'Facebook: le régulateur américain du commerce confirme enquêter',
#  "Les Sabres s'entendent avec Casey Mittelstadt",
#  'McDavid, Allen et Connor sont les trois étoiles de la semaine',
#  "L'Alberta pourrait perdre la moitié de sa forêt boréale",
#  'Sloane Stephens élimine Garbine Muguruza à Miami',
#  'Albert Belle arrêté pour outrage à la pudeur',
#  'Spotify prévoit une croissance de ses revenus ralentie en 2018',
#  "Aimia s'entend avec Mittleman Brothers avant l'assemblée des actionnaires",
#  'Kim Jong-un à Pékin: les spéculations vont bon train',
#  'Virgil Abloh nommé directeur artistique de Vuitton homme',
#  'Tournée Québec Cinéma: arrêts dans les Maritimes cette semaine',
#  "Erdogan remet l'adhésion sur la table avant un délicat sommet UE-Turquie",
#  'Marie-Andrée Labbé: défendre Céline Dion bec et ongles',
#  'Une entente sur le papier surcalandré pourrait offrir du répit à Résolu',
#  "Pas d'argent du cannabis aux villes dans le budget",
#  "Anne Fontaine: d'Eddy Bellegueule à Marvin",
#  'Laurel\xa0Halo: halo de poussière',
#  'Les professionnels du Laboratoire de santé publique en grève pendant 3\xa0jours',
#  "L'art de rue explose à Hong Kong",
#  'Red Wings: reconstruire avec des vétérans',
#  'Les 50 ans de Céline Dion',
#  "Un Mondial\xa02026 plus payant en Amérique du Nord qu'au Maroc",
#  'Anniversaire du décès de Prince: des hommages à Paisley Park',
#  'Aide sociale: Québec devance la gratuité des garderies subventionnées',
#  "Martin Brodeur et Sean Buke à la tête d'Équipe Canada",
#  'La Maison-Blanche dément toute liaison entre Donald Trump et Stormy Daniels',
#  'Un premier long métrage pour Adib Alkhalidey et Julien Lacroix',
#  'OuiSurf sur les vagues africaines',
#  "Encore deux semaines d'évaluation psychiatrique pour l'ex-otage Joshua Boyle",
#  "L'ex-patron du CN a touché 12,3\xa0millions en 2017",
#  'Haut les souliers!',
#  "Johnny Gaudreau s'absente pour des raisons familiales",
#  'Facebook toujours dans la tourmente',
#  "L'inspecteur général de Montréal pourrait partir prématurément",
#  'Programme Les Bâtisseuses: de la place pour 200\xa0bâtisseuses',
#  'Céline Dion: nos ex-«célinologues» se souviennent',
#  "Tuerie d'Orlando: le père du tireur était un informateur du FBI",
#  'La jeune militante Emma Gonzalez apparaît sur une photo truquée',
#  'Trois diplomates russes installés à Montréal expulsés',
#  'Le pétrole recule après sa meilleure semaine depuis huit mois',
#  'Clap final pour The Americans',
#  'Un livre sur Mélanie Cabay: du privilège de vieillir ****',
#  'REM: les\xa0discussions sont terminées, annonce Couillard',
#  "Baleines noires: les biologistes n'ont observé aucun nouveau-né cet hiver",
#  'Budget Leitão\xa02018: des chaussures commandées en ligne',
#  "Mode d'emploi pour conseils financiers - Planificateurs et compagnie",
#  "Mode d'emploi pour conseils financiers - Comment choisir\xa0?",
#  'Train de vie - Préparer sa retraite après les épreuves',
#  "Le BIG est intervenu dans l'attribution de contrats, selon son rapport annuel",
#  'Pont Champlain : Ottawa «maintient le cap» sur décembre 2018',
#  'Mondial 2026: Montréal dit avoir un soutien ferme de Québec et Ottawa',
#  'Twitter interdit certaines publicités liées aux cryptomonnaies',
#  'Impôts - Prévenez les vérifications fiscales\xa0!',
#  'Le Canada pourrait avoir des postes de précontrôle douanier aux États-Unis',
#  'Denis Shapovalov passe en huitièmes de finale à Miami',
#  "Au chessboxing, on s'affronte aux échecs et à la boxe",
#  "Les conservateurs s'attaquent au projet de loi sur le contrôle des armes à feu",
#  'Le chanteur du Bataclan dénigre les élèves de Parkland',
#  'John McCain va publier de nouveaux mémoires',
#  'Leitão\xa0présentera mardi un budget axé sur les dépenses',
#  "Brexit: l'intégrité du vote mise en doute par des lanceurs d'alerte",
#  'Ottawa veut des réformes électorales avant le prochain scrutin',
#  "Le projet d'oléoduc Trans Mountain obtient gain de cause devant la justice",
#  'Retour des Expos: Russell Martin refuse de se mouiller',
#  'Le blogueur Raïf Badawi reçoit un prix de journalisme\xa0',
#  "Les Américains croient que leur pays s'en va dans la mauvaise direction",
#  'Vladimir Guerrero fils heureux de revenir à Montréal',
#  "Cannabis: peu d'impact à la frontière américaine, selon Ottawa",
#  'Un gourou qui marquait par brûlure ses esclaves sexuelles arrêté',
#  'Prince avait une concentration excessive de fentanyl dans son corps',
#  "Troy Terry s'entend pour trois ans avec les Ducks",
#  "Égalité des sexes: les libéraux accusés d'hypocrisie",
#  'Les Hurricanes battent les Sénateurs 4-1',
#  'La série de gains à domicile des Maple Leafs prend fin',
#  'Black Panther détrôné au box-office par des robots',
#  'Islanders: Reimer signe un quatrième jeu blan',
#  'Gallagher atteint de nouveaux sommets dans la victoire',
#  'Scandale de favoritisme au Japon\xa0: le premier ministre ne serait pas impliqué',
#  "Gymnastique: arrestation de l'ex-patron de Larry Nassar",
#  "Le Lightning s'incline 4-1 contre les Coyotes",
#  'Les Capitals défont les Rangers 4-2',
#  "Les voitures autonomes d'Uber désormais interdites en Arizona",
#  "Grande barrière: essais prometteurs d'un film antisolaire",
#  'Spielberg va produire une série sur le conquistador Cortes',
#  "Trump n'a plus qu'un avocat...",
#  'Le chiffre du jour',
#  'Stormy à la une']

# %%
links['https://www.lapresse.ca/archives/2013/9/22.php']
# Out:
# ['https://www.lapresse.ca/voyage/trucs-conseils/201309/19/01-4691116-comment-se-rendre-a-new-york.php',
#  'https://www.lapresse.ca/arts/musique/critiques-cd/201309/20/01-4691383-chelsea-wolfe-douleur-et-beaute-.php',
#  'https://www.lapresse.ca/arts/musique/critiques-cd/201309/20/01-4691392-elvis-costello-the-roots-un-trip-de-grands-musiciens-.php',
#  'https://www.lapresse.ca/arts/musique/critiques-cd/201309/20/01-4691399-joseph-rouleau-un-terrifiant-boris-.php',
#  'https://www.lapresse.ca/arts/musique/critiques-cd/201309/20/01-4691408-azam-ali-loga-ramin-torkian-futur-anterieur-.php',
#  'https://www.lapresse.ca/arts/musique/critiques-cd/201309/20/01-4691417-jack-johnson-zone-de-confort-.php',
#  'https://www.lapresse.ca/arts/musique/critiques-cd/201309/20/01-4691421-chvrches-du-remplissage-.php',
#  'https://www.lapresse.ca/arts/musique/critiques-cd/201309/20/01-4691427-misteur-valaire-divertissement-consensuel-et-mondialise-.php',
#  'https://www.lapresse.ca/arts/musique/critiques-cd/201309/20/01-4691434-nadja-plus-de-tete-que-de-coeur-.php',
#  'https://www.lapresse.ca/arts/musique/critiques-cd/201309/20/01-4691445-guillaume-arsenault-elan-brise-12.php',
#  'https://www.lapresse.ca/maison/decoration/201309/20/01-4691565-prune-imprimes-textiles-beaux-linges.php',
#  'https://www.lapresse.ca/affaires/economie/energie-et-ressources/201309/20/01-4691579-dakota-du-nord-une-frenesie-qui-change-la-donne.php',
#  'https://www.lapresse.ca/affaires/economie/energie-et-ressources/201309/20/01-4691584-anticosti-moins-prometteur-que-le-dakota.php',
#  'https://www.lapresse.ca/vivre/mode/201309/20/01-4691587-dans-les-defiles-de-mode-etre-au-premier-rang-ou-ne-pas-etre.php',
#  'https://www.lapresse.ca/actualites/201309/21/01-4691741-au-nom-de-lhymen.php',
#  'https://www.lapresse.ca/arts/dossiers/festival-pop-montreal/201309/21/01-4691753-bazar-pop.php',
#  'https://www.lapresse.ca/actualites/201309/21/01-4691756-fermont-fermont.php',
#  'https://www.lapresse.ca/arts/spectacles-et-theatre/theatre/201309/21/01-4691762-mani-soleymanlou-et-emmanuel-schwartz-mani-sous-la-loupe.php',
#  'https://www.lapresse.ca/arts/musique/201309/21/01-4691766-thomas-fersen-lheureux-accident.php',
#  'https://www.lapresse.ca/arts/spectacles-et-theatre/danse/201309/21/01-4691770-festival-international-de-litterature-le-danseur-rapaille.php',
#  'https://www.lapresse.ca/arts/dossiers/festival-pop-montreal/201309/21/01-4691773-pop-montreal-large-volet-en-arts-visuels.php',
étrangers par Libanais interposés. Durant l’été\xa02006, le Canada n’a pas hésité à débourser 100\xa0millions pour venir en aide à nos concitoyens d’origine libanaise lors du conflit opposant Israël et le Hezbollah libanais. Plus de 15\xa0000\xa0personnes avaient été évacuées et rapatriées au Canada.  Bien sûr, les relations entre le Liban et le Canada ne se sont pas limitées à l’immigration. Les liens politiques, culturels, éducatifs, financiers et commerciaux se sont fortement développés. Pour illustrer la proximité des deux pays, il y a eu notamment la Lebanese Canadian Bank et quelques universités portant la mention «\xa0canadienne\xa0» dans leur nom. N’eût été la déstabilisation à peu près permanente qu’a subi le Liban de la part de ses voisins, nos relations seraient encore plus profondes. Rappelons-nous qu’au ...

# %%
#We count the number of data points.

count = 0
for key, value in articles.items(): 
    if isinstance(value, list): 
        count += len(value) 
print('Number of articles:', count)

count = 0
for key, value in titles.items(): 
    if isinstance(value, list): 
        count += len(value) 
print('Number of titles:', count)

count = 0
for key, value in links.items(): 
    if isinstance(value, list): 
        count += len(value) 
print('Number of links:', count)
# Out:
# Number of articles: 6904
# Number of titles: 6904
# Number of links: 6904

# %% [markdown]
# We put all the datas in a dataframe. We frst find the information about the category in the urls in the list 'links' and we create a dataframe for that information.

# %%
categories = {}
for url in links.keys():
    categories[url] = []
    for n in np.arange(0, len(links[url])):
        string = links[url][n].split("https://www.lapresse.ca/",1)[1].split("/", 1)[0]
        if string == 'arts': 
            string = 'culture'
        if string == 'cinema': 
            string = 'culture'
        #if string in lp_list:
        categories[url].append(string)

# %%
#We count the number of datas fitting in the categories we are interested in.

count = 0
for key, value in categories.items(): 
    if isinstance(value, list): 
        count += len(value) 
print('Number of articles:', count)
# Out:
# Number of articles: 6904

# %%
#Create empty Dataframe
df_lp = pd.DataFrame(columns = ['title', 'content', 'link', 'category'])

for url in categories.keys(): 
    df_temp = pd.DataFrame(columns = ['title', 'content', 'link', 'category'])
    df_temp['title'] = titles[url]
    df_temp['content'] = articles[url]
    df_temp['link'] = links[url]
    df_temp['category'] = categories[url]
    df_lp = df_lp.append(df_temp)

# %%
df_lp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6904 entries, 0 to 88
# Data columns (total 4 columns):
# title       6904 non-null object
# content     6904 non-null object
# link        6904 non-null object
# category    6904 non-null object
# dtypes: object(4)
# memory usage: 269.7+ KB

# %%
df_lp.sample(10)
# Out:
#                                                  title  \
# 113                     CPE: Québec lève son moratoire
# 50                  Ceux qui n'ont plus de pression...
# 48   Nouvelle vague de piratage: le Canada est mal ...
# 29                  Plan large sur le cinéma québécois
# 74   Scheer veut relancer les travaux du Parlement ...
# 40                                   Zaz est au Québec
# 28                Déjà dimanche!: un duo à apprivoiser
# 63             Baseball: paris risqués, paris gagnants
# 108  Les Sabres coupent les ailes des Wings en fusi...
# 96   Une femme tente de s'évader de prison en se fa...
#
#                                                content  \
# 113  La ministre de la Famille, Francine Charbonnea...
# 50   Le phénomène n'est pas nouveau. Le club est éc...
# 48   Ces derniers jours, les regroupements de pirat...
# 29   Si vous passez par le Quartier latin durant le...
# 74   (Ottawa) Le chef conservateur Andrew Scheer pr...
# 40   La populaire chanteuse française Zaz est à Mon...
# 28   Serons-nous des adeptes de Déjà dimanche !, le...
# 63   Tous les joueurs autonomes ne peuvent évidemme...
# 108  Tyler Ennis et Zemgus Girgensons ont touché la...
# 96   Une femme incarcérée à la prison de Sequedin, ...
#
#                                                   link    category
# 113  https://www.lapresse.ca/actualites/politique/p...  actualites
# 50   https://www.lapresse.ca/sports/hockey/poolers/...      sports
# 48   https://www.lapresse.ca/techno/internet/201107...      techno
# 29   https://www.lapresse.ca/cinema/cinema-quebecoi...     culture
# 74   https://www.lapresse.ca/actualites/politique/2...  actualites
# 40   https://www.lapresse.ca/arts/musique/201512/17...     culture
# 28   https://www.lapresse.ca/arts/television/201605...     culture
# 63   https://www.lapresse.ca/sports/baseball/201106...      sports
# 108  https://www.lapresse.ca/sports/hockey/201411/0...      sports
# 96   https://www.lapresse.ca/actualites/insolite/20...  actualites

# %% [markdown]
# Some articles do not fit in the categories we have decided to gather. We remove those rows.

# %%
#List of categories we want to gather
lp_list = ['actualites', 'international', 'affaires', 'sports', 'culture']

df_lp = df_lp[df_lp['category'].isin(lp_list)]

# %% [markdown]
# In retrospect, we would have put this code when we gathered the titles, links and article bodies, this would have saved some unnecessary computing. This will be done for the archive datas from Le Journal de Montreal.

# %%
df_lp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5706 entries, 3 to 88
# Data columns (total 4 columns):
# title       5706 non-null object
# content     5706 non-null object
# link        5706 non-null object
# category    5706 non-null object
# dtypes: object(4)
# memory usage: 222.9+ KB

# %%
df_lp.sample(10)
# Out:
#                                                  title  \
# 153         Les Américains célèbrent leur indépendance
# 90   Un vêtement pour bébé jugé offensant pour les ...
# 31               Montréal rend hommage à Julie Hamelin
# 58           JO de 2020: 15 nouvelles épreuves à Tokyo
# 75    Scott Dixon de nouveau vainqueur à Indianapolis
# 36   Accusations contre l'ex-patron de l'IAAF: «Le ...
# 183  L'acteur Stephen Collins soupçonné d'attouchem...
# 81   Le mystère des paraboles sur les huttes de cas...
# 124  Prince avait une concentration excessive de fe...
# 176     Londres a déjoué un complot terroriste de l'EI
#
#                                                content  \
# 153  Les Américains ont célébré, lundi, le 235e ann...
# 90   Walmart Canada a annoncé qu'il retirait de ses...
# 31   Le parc Jean-Rivard, situé dans la Cité des ar...
# 58   Un relais mixte 4 x 400 m en athlétisme et le ...
# 75   (Indianapolis) Finalement, Scott Dixon a de no...
# 36   «Tout vient des Britanniques» et de la volonté...
# 183  La police de Los Angeles a confirmé mardi réex...
# 81   (Ottawa) Au Canada, de mystérieuses paraboles ...
# 124  Un rapport de toxicologie découlant de l'autop...
# 176  La police et le Service de sécurité britanniqu...
#
#                                                   link       category
# 153  https://www.lapresse.ca/international/etats-un...  international
# 90   https://www.lapresse.ca/actualites/201707/14/0...     actualites
# 31   https://www.lapresse.ca/arts/spectacles-et-the...        culture
# 58   https://www.lapresse.ca/sports/autres-sports/o...         sports
# 75   https://www.lapresse.ca/sports/course-automobi...         sports
# 36   https://www.lapresse.ca/sports/autres-sports/a...         sports
# 183  https://www.lapresse.ca/arts/vie-de-stars/2014...        culture
# 81   https://www.lapresse.ca/actualites/insolite/20...     actualites
# 124  https://www.lapresse.ca/arts/musique/201803/26...        culture
# 176  https://www.lapresse.ca/international/europe/2...  international

# %%
df_lp.to_csv('articles_lapresse_archives.csv', header=True, index=True)
