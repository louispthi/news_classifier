# %% [markdown]
# # News scraping from the archives of Le Journal de Montreal

# %% [markdown]
# We use web scraping with the help of BeautifulSoup to create a dataset. This is a scraping of the archived news from Le Journal de Montreal, which we will use to train our models. We label our datas into 5 categories: 'Sports', 'Culture', 'Actualite', 'International' and 'Affaires'.

# %% [markdown]
# The archives in Le Journal de Montreal are already split into categories. We will obtain the news from 50 random days from 2016 to 2020 (10 per year) in each category. If we were to obtain all the datas from the same time period, this could influence the outcome, as they would probably be talking about similar subjects.

# %% [markdown]
# We import the relevant libraries.

# %%
from requests import get
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %% [markdown]
# The archives in La Presse are in a site which has an url of the form "https://www.journaldemontreal.com/CATEGORY/archives/DATE", where DATE has format YYYY/mm/dd and CATEGORY is the news category.

# %%
#Categories we are interested in
categories = ['actualite', 'monde', 'argent', 'sports', 'spectacles']

# %%
# Create a list of urls for 50 random dates
import random
random.seed(41)

years = list(range(2016, 2021))
urls = []
i = 0
days = [random.randint(1,28) for i in range(0,50)]
sdays=["%02d" % x for x in days]
months = [random.randint(1,12) for i in range(0,40)]
smonths = ["%02d" % x for x in months]

#2020 is not complete, so we make sure the date is from the past
months_2020 = [random.randint(1,8) for i in range(0,10)]
smonths_2020 = ["%02d" % x for x in months_2020]

for category in categories:
    while i <5: 
        j = 0
        year = str(years[i])
        while j < 10:
            n = 10*i + j
            day = sdays[n]
            if i == 4:
                month = smonths_2020[j]
            else:
                month = smonths[n]
            url_temp = 'https://www.journaldemontreal.com/' + category +'/archives/' + year + '/' + month + '/' + day
            urls.append(url_temp)
            j = j+1
        i = i+1
    i = 0

# %% [markdown]
# We make sure there are no duplicates.

# %%
len(urls) == len(set(urls))
# Out:
# True

# %% [markdown]
# We create requests.

# %%
#Requests
headers = {'Accept': 'text/html', 'User-Agent':'Mozilla/5.0'}
response_jdm = {}
for url in urls:
    response_jdm[url] = get(url, headers = headers)
    if response_jdm[url].status_code != 200:
        print("Status for", url, "is", response_jdm[url].status_code)

# %% [markdown]
# We create a soup.

# %%
#Save the main page content
mainpage_jdm = {}
for url in urls:
    mainpage_jdm[url] = response_jdm[url].content 

#Soup Creation 
soup_jdm = {}
for url in urls:
    soup_jdm[url] = BeautifulSoup(mainpage_jdm[url], 'html.parser')

# %% [markdown]
# We parse each article.

# %%
headline_jdm = {}
for url in urls:
    headline_jdm[url] = soup_jdm[url].find_all("article")
    #print(len(headline_jdm[url]))
headline_jdm[urls[2]][2]
# Out:
# <article class="archive actualite archive-block">
# <a href="https://www.journaldemontreal.com/2016/02/08/je-la-bonne-reaction-a-avoir-en-presence-dun-tireur-actif"><div class="lft"> <img alt="Attentat" src="https://storage.journaldemontreal.com/v1/dynamic_resize/sws_path/jdx-prod-images/886de9e0-8dcb-43c2-9452-d9f626ef4a5f_JDX-0x0_WEB.jpg?quality=80&amp;size=100x&amp;version=2" title="Attentat"> </img></div> <div class="rght"> <div class="vip-section-with-icon clearfix"> <div class="small-category-name float-left"> Faits divers </div> </div> <div class="title" labelproperty="Headline">Que faire face à un tueur ?</div> <div class="excerpt">Fuir, se cacher et attaquer, recommande la police.</div> <div class="last-update">MISE à JOUR <time datetime="2016-02-08T11:56:20Z"> Lundi, 8 février 2016 06:56 </time> </div> </div></a> </article>

# %%
articles = {}
titles = {}
links = {}

# Loop over each subsection in the dictionnary
for url in urls: 
    #Create lists
    articles[url] = []
    titles[url] = []
    links[url] = []
    
    #Loop over each article in a section 
    for n in np.arange(0, len(headline_jdm[url])):
        if headline_jdm[url][n].find('div', {'class': ['excerpt', 'title']}) is None:
            print('NonType in sub', url, 'number', n)
        else:
        
            #Access link to the article 
            link = headline_jdm[url][n].find('a')['href']
            
        
            #Getting the title
            title = headline_jdm[url][n].find('div', {'class': ['excerpt', 'title']}).get_text()
            
        
            #Getting the content of the article
            article = get(link)
            article_content = article.content
            soup_article = BeautifulSoup(article_content, 'html.parser')
            body = soup_article.find_all('div', {'class' : ['article-main-txt', 'formatted-text', 'caption']})
            if len(body) ==0:
                print('Empty body in sub', url, 'number', n)
            else: 
                x = body[0].find_all('p') 
        
            #Unifying the paragraphs
                list_paragraphs = []
                for p in np.arange(0, len(x)):
                    paragraph = x[p].get_text()
                    list_paragraphs.append(paragraph)
                    final_article = " ".join(list_paragraphs)
        
                articles[url].append(final_article)
                links[url].append(link)
                titles[url].append(title)
# Out:
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2016/11/13 number 15
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2016/01/11 number 27
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2016/02/08 number 42
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2016/02/08 number 44
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2016/12/19 number 10
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2016/03/23 number 47
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2016/01/10 number 9
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2016/01/10 number 12
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2016/01/10 number 23
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2016/05/18 number 14
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2016/05/18 number 34
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2016/06/09 number 17
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2017/04/13 number 41
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2017/10/25 number 13
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2017/10/19 number 46
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2017/07/25 number 38
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2017/01/08 number 21
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2017/01/08 number 22
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2018/03/01 number 45
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2018/02/15 number 40
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2018/02/05 number 13
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2018/02/05 number 43
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2018/02/05 number 49
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2018/01/11 number 1
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2018/01/11 number 3
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2018/11/06 number 25
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2019/08/19 number 22
# Empty body in sub https://www.journaldemontreal.com/actualite/archives/2019/09/10 number 44
# Empty body in sub https://www.journaldemontreal.com/monde/archives/2017/04/13 number 16
# Empty body in sub https://www.journaldemontreal.com/monde/archives/2018/02/05 number 17
# Empty body in sub https://www.journaldemontreal.com/argent/archives/2017/07/25 number 6
# Empty body in sub https://www.journaldemontreal.com/argent/archives/2017/07/27 number 10
# Empty body in sub https://www.journaldemontreal.com/sports/archives/2016/05/18 number 6
# Empty body in sub https://www.journaldemontreal.com/sports/archives/2017/07/25 number 21
# Empty body in sub https://www.journaldemontreal.com/spectacles/archives/2016/01/11 number 11
# Empty body in sub https://www.journaldemontreal.com/spectacles/archives/2016/01/11 number 13
# Empty body in sub https://www.journaldemontreal.com/spectacles/archives/2016/03/13 number 22
# Empty body in sub https://www.journaldemontreal.com/spectacles/archives/2016/01/10 number 8
# Empty body in sub https://www.journaldemontreal.com/spectacles/archives/2017/04/13 number 0
# Empty body in sub https://www.journaldemontreal.com/spectacles/archives/2017/04/13 number 6
# Empty body in sub https://www.journaldemontreal.com/spectacles/archives/2018/02/05 number 5
# Empty body in sub https://www.journaldemontreal.com/spectacles/archives/2018/07/23 number 7
# Empty body in sub https://www.journaldemontreal.com/spectacles/archives/2019/12/02 number 16
# Empty body in sub https://www.journaldemontreal.com/spectacles/archives/2019/07/28 number 5

# %% [markdown]
# We check a few examples to make sure that the algorithm worked.

# %%
titles[urls[2]]
# Out:
# ['Desjardins face à un tournant',
#  'La proportion d’autochtones a doublé',
#  'Que faire face à un tueur ?',
#  'Rien n’ébranle Couillard',
#  'Solution proposée pour les chauffeurs',
#  'Le suspect court toujours',
#  'Trois-Rivières procédera par appel d’offres',
#  'Les serriculteurs répliquent à Arcand',
#  'Une enquête publique est réclamée',
#  'Totalement légal selon la direction',
#  '[VIDEO] Un géant des mers frappé par une tempête',
#  'Une 5e ado fugue du Centre de Laval',
#  'Zampino se plaint du délai pour avoir la preuve',
#  "Trois employés blessés à l'urgence",
#  '200 taxis attendus autour du parlement mardi',
#  'Noémy Coderre retrouvée',
#  'Fin de carrière pour la voleuse sexy',
#  "500 emplois à Montréal d'ici 2020",
#  'Le pays? Faut espérer un effet Zanetti...',
#  'La plaignante l’a revu après la présumée agression',
#  'L’érosion linguistique',
#  'Un camionneur a le dessus sur l’assurance-emploi',
#  'QS écarte un rapprochement avec le PQ',
#  'Les Québécois ont la pire santé bucco-dentaire ',
#  'Une bretelle fermée pendant 6 heures',
#  "Finies les frappes contre l'ÉI d'ici le 22 février",
#  '500 grammes d’héroïne découverts ',
#  '3 personnes condamnées à payer 145 000$',
#  '220 M$ pour un «cadeau de Grec»',
#  ' Trouver l’âme sœur coûte de plus en plus cher',
#  "Voici comment savoir la note qu'ils vous donnent",
#  "Pas de prison pour avoir fraudé l'aide sociale",
#  'Finies les soirées privées',
#  'Comparution du tireur de Notre-Dame-de-Lourdes ',
#  'Risque accru de suicide chez les adultes',
#  'Doublement des naissances de jumeaux ',
#  'Un nouveau pas franchi mardi',
#  '«Sans oui, c’est non!»',
#  'Six mois pour attouchement sur une mineure',
#  'Le milieu municipal fait part de ses attentes',
#  'Physique: possible annonce majeure jeudi',
#  'Le gouvernement accusé d’avoir tabletté un rapport',
#  'Les élus conservateurs de Québec reçus par Hamad',
#  'Un chimiste et son fils resteront en prison',
#  'Calendrier serré pour la réforme scolaire ',
#  'Radiation préoccupante de 165 millions $ à la BN',
#  'Condamnés à un total de 140 ans de prison',
#  'Des publicités qui font jaser',
#  'La CAQ invite les parents à s’insurger',
#  'Rona Ambrose à Québec mardi',
#  "L'eau d'érable a coulé à flots ces derniers jours"]

# %%
links[urls[4]]
# Out:
# ['https://www.journaldemontreal.com/2016/03/13/montreal-un-homme-meurt-lors-dune-intervention-policiere',
#  'https://www.journaldemontreal.com/2016/03/13/un-batiment-industriel-brule-a-saint-jean-sur-richelieu-1',
#  'https://www.journaldemontreal.com/2016/03/13/plus-confiants-que-jamais',
#  'https://www.journaldemontreal.com/2016/03/14/elle-conduit-et-travaille-apres-avoir-perdu-ses-jambes',
#  'https://www.journaldemontreal.com/2016/03/13/un-cameleon-vieux-de-99-millions-dannees',
#  'https://www.journaldemontreal.com/2016/03/13/un-abri-dauto-qui-lave--la-voiture-en-plein-hiver',
#  'https://www.journaldemontreal.com/2016/03/12/jeunes-filles-piegees-par-leur-chum',
#  'https://www.journaldemontreal.com/2016/03/13/des-cours-de-langues-qui-ne-profitent-pas-a-des-refugies',
#  'https://www.journaldemontreal.com/2016/03/13/les-partisans-du-chboivent-et-mangent-moins',
#  'https://www.journaldemontreal.com/2016/03/13/elle-se-tue-au-volant-apres-18h-de-travail',
#  'https://www.journaldemontreal.com/2016/03/13/un-lundi-difficile-a-lhorizon',
#  'https://www.journaldemontreal.com/2016/03/13/abolition-du-delai-de-prescription-reclamee',
#  'https://www.journaldemontreal.com/2016/03/13/le-rapport-godbout-tablette-en-douce',
#  'https://www.journaldemontreal.com/2016/03/13/fermeture-du-pavillon-sainte-marie-des-parents-de-residents-font-appel-a-la-justice',
#  'https://www.journaldemontreal.com/2016/03/13/deux-hommes-sombrent-dans-le-lac-magog-en-estrie',
#  'https://www.journaldemontreal.com/2016/03/13/le-parti-quebecois-reclame-la-suspension-duberx',
#  'https://www.journaldemontreal.com/2016/03/13/un-homme-a-peut-etre-urine-dans-vos-cereales',
#  'https://www.journaldemontreal.com/2016/03/13/petition-des-pompiers-de-rosemere-la-municipalite-denonce-une-campagne-de-peur',
#  'https://www.journaldemontreal.com/2016/03/13/mairie-de-montreal-nord-kerlande-mibel-candidate-pour-projet-montreal',
#  'https://www.journaldemontreal.com/2016/03/13/saint-isidoredemande-laide-de-tous-les-quebecois',
#  'https://www.journaldemontreal.com/2016/03/13/dur-passage-pour-le-ministre-barrette-a-tout-le-monde-en-parle',
#  'https://www.journaldemontreal.com/2016/03/13/luniversite-laval-modifie-le-visuel-de-sa-campagne-de-financement',
#  'https://www.journaldemontreal.com/2016/03/13/le-defi-ski-12-h-leucan-permet-damasser-145-000--pour-les-enfants-atteints-de-cancer',
#  'https://www.journaldemontreal.com/2016/03/13/agressions-sexuelles-la-caq-veut-abolir-le-delai-de-prescription-pour-les-victimes',
#  'https://www.journaldemontreal.com/2016/03/13/un-homme-attaque-a-larme-blanche-dans-saint-michel',
#  'https://www.journaldemontreal.com/2016/03/13/vos-preferes-moins-chers-en-ontario',
#  'https://www.journaldemontreal.com/2016/03/13/trois-rivieres-des-papas-apprennent-a-coiffer-leur-fillette',
#  'https://www.journaldemontreal.com/2016/03/13/une-journee-parfaite-pour-etre-dehors',
#  'https://www.journaldemontreal.com/2016/03/13/rappel-de-lait-au-chocolat-de-marque-beatrice',
#  'https://www.journaldemontreal.com/2016/03/13/le-printemps-sinstalle',
#  'https://www.journaldemontreal.com/2016/03/13/une-allumette-cause-un-incendie-dans-un-immeuble-a-logements',
#  'https://www.journaldemontreal.com/2016/03/13/la-fillette-succombe-a-ses-blessures',
#  'https://www.journaldemontreal.com/2016/03/13/une-fillette-dans-un-etat-critique-apres-une-collision-a-laval',
#  'https://www.journaldemontreal.com/2016/03/13/nue-devant-8-ados-sur-sa-webcam']

# %%
(articles[urls[6]])[2]
# Out:
# ' Surnommé le «roi du cannabis», le controversé homme d’affaires à la tête d’une chaîne de commerces qui vend de la marijuana médicale confirme qu’il aura très bientôt pignon sur rue à Montréal.  «On s’en vient», assure Don Briere au sujet de sa chaîne Weeds Glass & Gifts, qui compte déjà près d’une vingtaine de boutiques en Colombie-Britannique et en Ontario.  Il soutient qu’il a signé un bail sur la rue Saint-Denis, près de la rue Rachel. Cependant, il refuse d’en dévoiler l’adresse exacte avant d’y installer un système de sécurité puisque ses commerces, dit-il, sont souvent la cible des voleurs.  Chez Labeaume  Don Briere ne compte pas s’arrêter à Montréal non plus, puisqu’il a aussi Québec dans sa mire. Selon lui, l’arrivée au pouvoir de Justin Trudeau, qui a promis de légaliser la marijuana, est le moment idéal pour continuer son expansion.  La vente de marijuana en magasin reste illégale au Canada, mais celui qui est souvent surnommé le «roi du cannabis» profite d’une zone grise sur la marijuana médicale pour mener ses activités.  Normalement, seul un patient avec une prescription peut entrer en contact avec un producteur accrédité par Santé Canada et recevoir sa marijuana médicale par la poste.  «La demande augmente sans cesse, on ne fournit pas», lance Don Brire, dont les commerces sont aussi populaires que controversé.  Mauvaise réputation  Les boutiques Weeds Glass & Gifts ont en effet la réputation d’être très laxistes. Des documents de cour obtenus par le Vancouver Sun démontraient qu’un policier avait pu s’y procurer du cannabis sans aucune prescription et qu’une adolescente en avait aussi fait l’achat.  Des jeunes auraient aussi été admis à l’hôpital pour traiter des hallucinations après avoir consommé du cannabis acheté dans l’une de ses boutiques de Vancouver.  M. Briere a aussi un lourd passé criminel. Il a notamment été arrêté à plusieurs reprises pour possession et trafic de marijuana de 1972 à 2008.  Malgré tout, Don Briere se présente en grand défenseur de la marijuana. «L’alcool tue plus de gens que la marijuana, l’industrie pharmaceutique fait de nombreuses erreurs», répond-il, lorsqu’interrogé sur la qualité de ses produits.  L’arrivée prochaine d’un commerce de M. Briere à Montréal ne présage rien de bon, selon Marc-Boris Saint-Maurice, fondateur du Centre compassion qui vend de la marijuana médicale à Montréal.  « Tout croche »  «Je ne veux pas que quelqu’un comme lui qui fait ça tout croche vienne brasser la cage», dit-il, craignant de perdre de la crédibilité aux yeux des autorités qui le laisse tranquille depuis des années.  Il assure que son centre ne vend qu’à des clients qui ont une prescription en bonne et due forme.  L’administration du Plateau Mont-Royal indique quant à elle qu’elle se penche sur la gestion de ces boutiques sur son territoire.  Pour sa part, l’Association industrielle canadienne du cannabis médical est catégorique: elle réclame qu’Ottawa mette la clé à la porte de toutes les boutiques qui vendent illégalement de la marijuana médicale.'

# %%
#We count the number of data points.

def count(dictionnary, name):
    c = 0
    for key, value in dictionnary.items(): 
        if isinstance(value, list): 
            c += len(value) 
    print('Number of '+ name + ':', c)

count(articles, 'articles')
count(titles, 'titles')
count(links, 'links')
# Out:
# Number of articles: 6696
# Number of titles: 6696
# Number of links: 6696

# %% [markdown]
# We put all the datas in a dataframe. We frst find the information about the category in the urls and we create a dataframe for that information.

# %%
categories = {}
for url in links.keys():
    categories[url] = []
    for n in np.arange(0, len(links[url])):
        string = url.split('https://www.journaldemontreal.com/',1)[1].split("/", 1)[0]
        if string == 'spectacles': 
            string = 'culture'
        if string == 'sports': 
            string = 'sports'
        if string == 'argent': 
            string = 'affaires'
        if string == 'monde':
            string = 'international'
        if string == 'actualite':
            string = 'actualites'
        categories[url].append(string)

# %%
categories[urls[60]]
# Out:
# ['international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international',
#  'international']

# %%
count(categories, 'categories')
# Out:
# Number of categories: 6696

# %%
#Create empty Dataframe
df_jdm = pd.DataFrame(columns = ['title', 'content', 'link', 'category'])

for url in categories.keys(): 
    df_temp = pd.DataFrame(columns = ['title', 'content', 'link', 'category'])
    df_temp['title'] = titles[url]
    df_temp['content'] = articles[url]
    df_temp['link'] = links[url]
    df_temp['category'] = categories[url]
    df_jdm = df_jdm.append(df_temp)

# %%
df_jdm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6696 entries, 0 to 15
# Data columns (total 4 columns):
# title       6696 non-null object
# content     6696 non-null object
# link        6696 non-null object
# category    6696 non-null object
# dtypes: object(4)
# memory usage: 261.6+ KB

# %%
df_jdm.sample(20)
# Out:
#                                                  title  \
# 26     Un entraîneur-chef par intérim pour les Jaguars
# 20            26 arrestations en France et en Belgique
# 9                                  10 meilleurs matchs
# 20           Un pétrolier s’est échoué près de la côte
# 18                         Lourde perte pour les Stars
# 45                                       Lune de guêpe
# 3       Le ministre de la Justice sous le feu de Trump
# 30                    Huit arrestations à Saint-Jérôme
# 7                Allemagne: pas encore de gouvernement
# 3                        Une distribution toute étoile
# 3             Pour sa fête, elle gâtera des itinérants
# 17               La présumée victime contre-interrogée
# 14              Tournage en isolement avec mes parents
# 145               La courbe américaine «va être laide»
# 16             Le BEI enquête sur le décès d’un détenu
# 20                        Ces grands qui disparaissent
# 24     Prime de 2 $ l’heure pour les employés d’Olymel
# 0                                 Quoi regarder lundi?
# 13       [VIDÉOS] Un tireur de 19 ans sème la terreur
# 8    Kovrig soupçonné d’espionnage, Trudeau «préocc...
#
#                                                content  \
# 26    Au lendemain du congédiement de l’entraîneur-...
# 20   Treize personnes ont été arrêtées en Belgique ...
# 9     La NFL célébrera aujourd’hui à San Francisco ...
# 20    CAP-BRETON, N.-É. | Un hélicoptère Cormorant ...
# 18    Opéré à une main vendredi, le défenseur des S...
# 45    Après plus de 100 jours passés à diriger Mont...
# 3     WASHINGTON |Le ministre américain de la Justi...
# 30    SAINT-JÉRÔME | Les policiers ont arrêté huit ...
# 7     BERLIN | La chancelière allemande Angela Merk...
# 3     Plusieurs visages bien connus du petit écran ...
# 3     ROBERVAL | Une femme du Lac-Saint-Jean profit...
# 17   ***Avertissement, certains propos contenus dan...
# 14   La troisième saison de Discussions avec mes pa...
# 145  Si toutes les courbes montrant l’évolution de ...
# 16    MONTRÉAL | Le Bureau des enquêtes indépendant...
# 20    Voilà qu’un autre grand bâtisseur du Québec, ...
# 24   En pleine crise de la COVID-19, l’entreprise O...
# 0    MONTRÉAL | Voici quelques suggestions d'émissi...
# 13    LOS ANGELES | Au moins trois personnes, dont ...
# 8     Les autorités chinoises soupçonnent l’ex-dipl...
#
#                                                   link       category
# 26   https://www.journaldemontreal.com/2016/12/19/u...         sports
# 20   https://www.journaldemontreal.com/2020/05/27/c...  international
# 9    https://www.journaldemontreal.com/2016/02/06/1...         sports
# 20   https://www.journaldemontreal.com/2017/01/08/u...     actualites
# 18   https://www.journaldemontreal.com/2018/11/09/l...         sports
# 45   https://www.journaldemontreal.com/2018/02/15/l...     actualites
# 3    https://www.journaldemontreal.com/2017/07/25/d...  international
# 30   https://www.journaldemontreal.com/2018/11/09/t...     actualites
# 7    https://www.journaldemontreal.com/2018/01/11/a...  international
# 3    https://www.journaldemontreal.com/2016/03/23/l...        culture
# 3    https://www.journaldemontreal.com/2018/11/09/p...     actualites
# 17   https://www.journaldemontreal.com/2020/02/18/e...     actualites
# 14   https://www.journaldemontreal.com/2020/05/27/t...        culture
# 145  https://www.journaldemontreal.com/2020/03/24/l...     actualites
# 16   https://www.journaldemontreal.com/2018/11/06/s...     actualites
# 20   https://www.journaldemontreal.com/2018/11/09/c...     actualites
# 24   https://www.journaldemontreal.com/2020/03/24/c...       affaires
# 0    https://www.journaldemontreal.com/2020/08/03/q...        culture
# 13   https://www.journaldemontreal.com/2019/07/28/c...  international
# 8    https://www.journaldemontreal.com/2019/03/04/c...     actualites

# %%
df_jdm.to_csv('articles_le_journal_de_montreal_archives.csv', header=True, index=True)
