# %% [markdown]
# # News scraping for Le Journal de Montreal

# %% [markdown]
# We use web scraping with the help of BeautifulSoup to create a dataset. This is a scraping of the newest news, which is useful for acquiring new datas every day. We label our datas into 5 categories: 'Sports', 'Culture', 'Actualite', 'International' and 'Affaires'.

# %% [markdown]
# We import the relevant libraries.

# %%
from requests import get
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %% [markdown]
# ### Le Journal de Montreal

# %% [markdown]
# We use web scraping to get datas from Le Journal de Montreal. We will access different subpages, so we create dictionnaries for all of them.

# %%
#Put the different subsections into a list
#Actualites 
sub_act_list = ['faits-divers', 'politique', 'nos-routes-en-deroute', 'sante', 
               'cannabis', 'education', 'transports', 'environnement', 
               'consommation', 'societe']
#International 
sub_int_list = ['etats-unis', 'ameriques', 'europe', 'moyen-orient', 
               'asie-pacifique', 'afrique']

#Affaires 
sub_aff_list = ['dans-vos-poches', 'penurie-de-main-doeuvre', 'reer', 
               'ou-vont-vos-impots', 'entreprises', 'bourse', 'PMEinc']
#Sports 
sub_spo_list = ['hockey', 'tennis', 'baseball', 
                'football', 'plein-air-chasse-et-peche', 
               'combats', 'courses', 'soccer', 'golf', 'ski', 'autres-sports']
#Culture 
sub_cul_list = ['jetset', 'cinema', 'television', 'musique', 'spectacles', 
               'theatre', 'sorties','humour']

#Concatenated list 
sub_jdm_list = sub_act_list +sub_int_list + sub_aff_list + sub_spo_list + sub_cul_list 
    
#url definitinons 
url = {}
for sub in sub_act_list:
    sub_url = "https://www.journaldemontreal.com/actualite/" + sub
    url[sub] = sub_url
for sub in sub_int_list:
    sub_url = "https://www.journaldemontreal.com/monde/" + sub
    url[sub] = sub_url
for sub in sub_aff_list:
    sub_url = "https://www.journaldemontreal.com/argent/" + sub
    url[sub] = sub_url
for sub in sub_spo_list:
    sub_url = "https://www.journaldemontreal.com/sports/" + sub
    url[sub] = sub_url
for sub in sub_cul_list:
    sub_url = "https://www.journaldemontreal.com/spectacles/" + sub
    url[sub] = sub_url

# %% [markdown]
# We create requests.

# %%
#Requests
headers = {'Accept': 'text/html', 'User-Agent':'Mozilla/5.0'}
response_jdm = {}
for sub in sub_jdm_list:
    response_jdm[sub] = get(url[sub], headers = headers)
    print("Status for", sub, "is", response_jdm[sub].status_code)
# Out:
# Status for faits-divers is 200
# Status for politique is 200
# Status for nos-routes-en-deroute is 200
# Status for sante is 200
# Status for cannabis is 200
# Status for education is 200
# Status for transports is 200
# Status for environnement is 200
# Status for consommation is 200
# Status for societe is 200
# Status for etats-unis is 200
# Status for ameriques is 200
# Status for europe is 200
# Status for moyen-orient is 200
# Status for asie-pacifique is 200
# Status for afrique is 200
# Status for dans-vos-poches is 200
# Status for penurie-de-main-doeuvre is 200
# Status for reer is 200
# Status for ou-vont-vos-impots is 200
# Status for entreprises is 200
# Status for bourse is 200
# Status for PMEinc is 200
# Status for hockey is 200
# Status for tennis is 200
# Status for baseball is 200
# Status for football is 200
# Status for plein-air-chasse-et-peche is 200
# Status for combats is 200
# Status for courses is 200
# Status for soccer is 200
# Status for golf is 200
# Status for ski is 200
# Status for autres-sports is 200
# Status for jetset is 200
# Status for cinema is 200
# Status for television is 200
# Status for musique is 200
# Status for spectacles is 200
# Status for theatre is 200
# Status for sorties is 200
# Status for humour is 200

# %% [markdown]
# We create a soup.

# %%
#Save the main page content
mainpage_jdm = {}
for sub in sub_jdm_list:
    mainpage_jdm[sub] = response_jdm[sub].content 

#Soup Creation 
soup_jdm = {}
for sub in sub_jdm_list:
    soup_jdm[sub] = BeautifulSoup(mainpage_jdm[sub], 'html.parser')

# %% [markdown]
# We parse each article.

# %%
headline_jdm = {}
for sub in sub_jdm_list:
    headline_jdm[sub] = soup_jdm[sub].find_all("article")
    #print(len(headline_jdm[sub]))
headline_jdm['combats'][0]
# Out:
# <article class="item-inner">
# <div class="ab-testing ab-test__default">
# <div class="show-comments">
# </div>
# </div>
# <div class="ab-testing ab-test__variant">
# <div class="show-comments">
# </div>
# </div>
# <a href="https://www.journaldemontreal.com/2020/09/03/une-scene-transformee-en-ring"><div class="title-box"> <div class="title-wrapper"> <div class="hidden-content"> <p class="sub-title">Québecor veut présenter des galas au Capitole, une salle qu’elle a achetée en juin.</p> </div> <div class="hints"> <span class="strapline">Boxe</span> </div> <h2 class="main-title"> Théâtre Capitole: une scène transformée en ring </h2> </div> </div> <picture> <!--[if IE 9]><video style="display: none;"><![endif]--> <source media="(min-width: 40em)" srcset="https://m1.quebecormedia.com/emp/emp/62754806_0879286acf0970-47ad-48b3-aac4-b4b54073b61d_ORIGINAL.jpg?impolicy=crop-resize&amp;x=145&amp;y=135&amp;w=1353&amp;h=1090&amp;width=764, https://m1.quebecormedia.com/emp/emp/62754806_0879286acf0970-47ad-48b3-aac4-b4b54073b61d_ORIGINAL.jpg?impolicy=crop-resize&amp;x=145&amp;y=135&amp;w=1353&amp;h=1090&amp;width=1528 2x"/> <!--[if IE 9]></video><![endif]--> <img alt="chantier Capitole" class="item-img Story" srcset="https://m1.quebecormedia.com/emp/emp/62754806_0879286acf0970-47ad-48b3-aac4-b4b54073b61d_ORIGINAL.jpg?impolicy=crop-resize&amp;x=145&amp;y=135&amp;w=1353&amp;h=1090&amp;width=378, https://m1.quebecormedia.com/emp/emp/62754806_0879286acf0970-47ad-48b3-aac4-b4b54073b61d_ORIGINAL.jpg?impolicy=crop-resize&amp;x=145&amp;y=135&amp;w=1353&amp;h=1090&amp;width=756 2x"/> </picture></a> </article>

# %% [markdown]
# From this, we see that we can easily extract the title and the description of each article, as well as the link for the complete article. We will use that to go to the article and extract the title and full text.

# %%
articles = {}
titles = {}
links = {}

# Loop over each subsection in the dictionnary
for sub in sub_jdm_list: 
    #Create lists
    articles[sub] = []
    titles[sub] = []
    links[sub] = []
    
    #Loop over each article in a section 
    for n in np.arange(0, len(headline_jdm[sub])):
        if headline_jdm[sub][n].find('h2', {'class': ['main-title', 'medium ', 'short ']}) is None:
            print('NonType in sub', sub, 'number', n)
        else:
        
            #Access link to the article 
            link = headline_jdm[sub][n].find('a')['href']
            links[sub].append(link)
        
            #Getting the title
            title = headline_jdm[sub][n].find('h2', {'class': ['main-title', 'medium ', 'short ']}).get_text()
            titles[sub].append(title)
        
            #Getting the content of the article
            article = get(link)
            article_content = article.content
            soup_article = BeautifulSoup(article_content, 'html.parser')
            body = soup_article.find_all('div', {'class' : ['article-main-txt', 'formatted-text']})
            if len(body) ==0:
                print('Empty body in sub', sub, 'number', n)
            else: 
                x = body[0].find_all('p') 
        
            #Unifying the paragraphs
                list_paragraphs = []
                for p in np.arange(0, len(x)):
                    paragraph = x[p].get_text()
                    list_paragraphs.append(paragraph)
                    final_article = " ".join(list_paragraphs)
        
                articles[sub].append(final_article)

# %% [markdown]
# We make sure that the algorithm worked.

# %%
titles['combats']
# Out:
# [' Théâtre Capitole: une scène transformée en ring ',
#  ' Hugo Girard est jugé sans avoir été avisé ',
#  ' La ministre confirme l’absence de communication ',
#  ' Une année de défis pour Gill ',
#  ' Estephan pourrait devoir patienter ',
#  ' Les sports de combat reprendront au Québec ',
#  ' Combat en vue pour Charles Jourdain ',
#  ' Feu vert pour la boxe pro ',
#  'La guerre de Sécession n’a rien changé',
#  ' «Je boycotterais mon combat» –Jean Pascal ',
#  ' Le tout pour le tout pour Zewski ',
#  " «C'est le combat que j'attendais» - Mikaël Zewski ",
#  ' «Il doit être honnête avec lui-même» ',
#  ' Artur Beterbiev change d’adversaire ',
#  ' Le chant du cygne pour Alvarez ',
#  'Plus rien à donner... reste une saison',
#  ' Dure défaite d’Alvarez ',
#  ' Une pesée sans histoire ']

# %%
links['politique']
# Out:
# ['https://www.journaldemontreal.com/2020/09/06/limpuissance-des-politiciens',
#  'https://www.journaldemontreal.com/2020/09/06/des-slogans-a-une-vraie-strategie-economique',
#  'https://www.journaldemontreal.com/2020/09/06/la-grc-avait-a-lil-les-independantistes',
#  'https://www.journaldemontreal.com/2020/09/06/le-chef-conservateur-veut-reunir-les-deux-solitudes',
#  'https://www.journaldemontreal.com/2020/09/06/berlin-critique-lappel-de-trump-a-voter-deux-fois',
#  'https://www.journaldemontreal.com/2020/09/06/le-quebec-en-deconfinement-la-pandemie-aura-eu-du-bon',
#  'https://www.journaldemontreal.com/2020/09/06/le-quebec-en-deconfinement-10-moments-marquants-de-la-crise-sanitaire',
#  'https://www.journaldemontreal.com/2020/09/05/premiere-journee-de-vote-par-anticipation-au-nouveau-brunswick',
#  'https://www.journaldemontreal.com/2020/09/05/la-dissolution-du-parti-quebecois-preconisee-par-un-de-ses-fondateurs',
#  'https://www.journaldemontreal.com/2020/09/05/taxe-carbone--les-autocollants-dans-les-stations-service-ontariennes-sont-anticonstitutionnels',
#  'https://www.journaldemontreal.com/2020/09/05/entrevue--les-choses-sont-en-train-de-changer-pour-les-femmes-en-politique',
#  'https://www.journaldemontreal.com/2020/09/05/le-show-de-boucane',
#  'https://www.journaldemontreal.com/2020/09/05/rene-levesque-espionne',
#  'https://www.journaldemontreal.com/2020/09/05/ces-engagements-dune-autre-epoque']

# %%
articles['cinema']
# Out:
accident. Le motocycliste a été transporté en centre hospitalier, et son décès a été constaté peu de temps après.  Que tu vas me manquer mon amour de papa. Tu es ma fierté. Tu es mon modèle. Merci de tout m'avoir appris. Samedi Nos yeux bleus minuit se sont noyés un instant dans l'océan de notre amour et tu es mort dans mes bras. Je t'aime. Pour toujours. Ta fille Une publication partagée par  Anik Jean (@anikjeanh) le 31 Août 2020 à 4 :10 PDT Artiste et aventurier\xa0 C’est la firme Roy & Turner Communications qui a annoncé, lundi, qu’il s’agissait en fait de Roland Jean, le père de l’auteure-compositrice-interprète Anik Jean. Artiste comme sa fille, mais aussi aventurier, l’homme était âgé de 74 ans au moment de son trépas. «\xa0Bien connu de sa communauté, [...] Roland Jean laisse plusieurs personnes dans le deuil. Tous ceux qui ont croisé son chemin ont été touchés par son optimisme et sa générosité\xa0», peut-on lire dans un communiqué diffusé par la firme de communications. Souhaitant vivre son deuil en privé, Anik Jean a refusé de répondre aux demandes d’entrevue. Il y a une dizaine de jours, l’artiste a toutefois connu des moments beaucoup plus heureux. En effet, elle a célébré ses neuf ans de mariage avec Patrick Huard. Le couple s’est marié le 21 août 2011. Les deux amoureux sont les parents de Nathan, un garçon âgé de 8 ans.\xa0 – Avec l’Agence QMI\xa0",
#  'Premier blockbuster\xa0hollywoodien à prendre l’affiche depuis le début de la pandémie, le thriller Tenet a répondu aux attentes en récoltant plus de 53 millions de dollars au box-office international pendant ses cinq premiers jours d’exploitation.  Annoncé depuis des semaines comme le sauveur des salles de cinéma, le très attendu nouveau film de Christopher Nolan (Dunkerque, Inception) a été lancé en grande pompe, mercredi dernier, dans une quarantaine de pays (dont le Canada), quelques jours avant sa sortie américaine, prévue ce vendredi. Selon les premiers résultats compilés par le site spécialisé Deadline Hollywood, Tenet a amassé 7,1\xa0M$ au Royaume-Uni, 6,7\xa0M$ en France, 5,1\xa0M$ en Corée et 4,2\xa0M$ en Allemagne. Le studio Warner Brothers a refusé de dévoiler\xa0les premiers résultats pour le box-office canadien, mais les exploitants de salles au Québec se sont dits satisfaits de la performance du film. \xa0 Prometteur «\xa0C’est une très bonne performance, surtout quand on sait que c’est un film à la James Bond et qu’un grand nombre d’adultes étaient occupés à préparer la rentrée scolaire de leurs enfants\xa0», a indiqué le président des Cinémas Guzzo, Vincent Guzzo.\xa0 «\xa0C’est très prometteur pour la suite des choses. Je crois que c’est un film qui restera à l’affiche longtemps.\xa0» M.\xa0Guzzo estime que la sortie de Tenet ainsi que celle du film Les nouveaux mutants, nouveau chapitre de la saga X-Men ont\xa0considérablement fait augmenter l’achalandage dans ses complexes la fin de semaine dernière. La pluie qui est tombée sur plusieurs régions du Québec, samedi, a aussi contribué à attirer plus de cinéphiles dans les salles. «\xa0Notre chiffre d’affaires, en fin de semaine, était à\xa061\xa0% de ce qu’on a fait pendant le même week-end l’an passé\xa0», a souligné M.\xa0Guzzo.\xa0']

# %%
count = 0
for key, value in articles.items(): 
    if isinstance(value, list): 
        count += len(value) 
print(count)
# Out:
# 704

# %% [markdown]
# We now put all the datas into a Dataframe.

# %%
#Create empty Dataframe
df_jdm = pd.DataFrame(columns = ['title', 'content', 'link', 'category'])

#Actualites
for sub in sub_act_list: 
    df_temp = pd.DataFrame(columns = ['title', 'content', 'link', 'category'])
    df_temp['title'] = titles[sub]
    df_temp['content'] = articles[sub]
    df_temp['link'] = links[sub]
    df_temp['category'] = 'actualites'
    df_jdm = df_jdm.append(df_temp)
    
#International
for sub in sub_int_list: 
    df_temp = pd.DataFrame(columns = ['title', 'content', 'link', 'category'])
    df_temp['title'] = titles[sub]
    df_temp['content'] = articles[sub]
    df_temp['link'] = links[sub]
    df_temp['category'] = 'international'
    df_jdm = df_jdm.append(df_temp)

#Affaires
for sub in sub_aff_list: 
    df_temp = pd.DataFrame(columns = ['title', 'content', 'link', 'category'])
    df_temp['title'] = titles[sub]
    df_temp['content'] = articles[sub]
    df_temp['link'] = links[sub]
    df_temp['category'] = 'affaires'
    df_jdm = df_jdm.append(df_temp)

#Sports
for sub in sub_spo_list: 
    df_temp = pd.DataFrame(columns = ['title', 'content', 'link', 'category'])
    df_temp['title'] = titles[sub]
    df_temp['content'] = articles[sub]
    df_temp['link'] = links[sub]
    df_temp['category'] = 'sports'
    df_jdm = df_jdm.append(df_temp)

#Culture
for sub in sub_cul_list: 
    df_temp = pd.DataFrame(columns = ['title', 'content', 'link', 'category'])
    df_temp['title'] = titles[sub]
    df_temp['content'] = articles[sub]
    df_temp['link'] = links[sub]
    df_temp['category'] = 'culture'
    df_jdm = df_jdm.append(df_temp)

# %%
df_jdm.sample(10)
# Out:
#                                                 title  \
# 12            Les Red Bulls limogent leur entraîneur
# 12    Trump met fin aux formations contre le racisme
# 4        La maison de vos rêves grâce à la pandémie?
# 10                    Automne intime pour le Trident
# 1        Cinq blessés dans un accident spectaculaire
# 5                     Nana se dirige vers le Mexique
# 16   Nemaska Lithium plusieurs fois dénoncée à l’AMF
# 7    De publicitaire à fabricant de produits sanit...
# 10    Le virus ferme les pubs et assèche la campagne
# 4                      Indétrônable, le Kim Crawford
#
#                                               content  \
# 12  Les Red Bulls de New York ont annoncé avoir mi...
# 12  Washington | Le président américain, Donald Tr...
# 4   Du «jamais-vu» depuis 40 ans. Voilà comment es...
# 10  Le Trident investira quatre lieux pour sa rela...
# 1   Cinq personnes ont été blessées dans un accide...
# 5   L’ouragan Nana, qui a rapidement perdu de sa p...
# 16  La minière Nemaska Lithium, dans laquelle Québ...
# 7   Après 12 ans dans le milieu de la pub, Fayçal ...
# 10  Dans les pubs de Dunmore, les verres de Guinne...
# 4   Le vin blanc Kim Crawford, qui est offert dans...
#
#                                                  link       category
# 12  https://www.journaldemontreal.com/2020/09/04/l...         sports
# 12  https://www.journaldemontreal.com/2020/09/05/t...  international
# 4   https://www.journaldemontreal.com/2020/09/06/l...     actualites
# 10  https://www.journaldemontreal.com/2020/08/17/a...        culture
# 1   https://www.journaldemontreal.com/2020/09/06/m...     actualites
# 5   https://www.journaldemontreal.com/2020/09/03/l...  international
# 16  https://www.journaldemontreal.com/2020/09/03/n...       affaires
# 7   https://www.journaldemontreal.com/2020/06/17/d...       affaires
# 10  https://www.journaldemontreal.com/2020/09/05/e...  international
# 4   https://www.journaldemontreal.com/2020/09/05/s...       affaires

# %%
df_jdm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 704 entries, 0 to 17
# Data columns (total 4 columns):
# title       704 non-null object
# content     704 non-null object
# link        704 non-null object
# category    704 non-null object
# dtypes: object(4)
# memory usage: 27.5+ KB

# %% [markdown]
# We now save this into a csv file. Since we will do this for different days, we create a string with the date.

# %%
from datetime import date

today = date.today()
day = today.strftime("%m%d%y")
print("The day in string format is =", day)

#Create a string for the csv file
file = 'articles_journal_de_montreal_' + day + '.csv'
print("File name: ", file)
# Out:
# The day in string format is = 090620
# File name:  articles_journal_de_montreal_090620.csv

# %%
df_jdm.to_csv(file, header=True, index=True)
